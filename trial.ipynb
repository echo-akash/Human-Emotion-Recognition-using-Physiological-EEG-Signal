# %%
import pandas as pd

# %%
df = pd.read_csv("Disgust/1.csv")

# %%
df
# Out:
#       timestampMs  poorSignal  eegRawValue  eegRawValueVolts  attention  \
# 0   1566625184526          25           17      3.735352e-06          0
# 1   1566625185527          25         -118     -2.592773e-05          0
# 2   1566625186527           0           60      1.318359e-05          0
# 3   1566625187538           0         -171     -3.757324e-05          0
# 4   1566625188546           0          120      2.636719e-05          0
# 5   1566625189553           0           41      9.008789e-06         54
# 6   1566625190560           0           32      7.031250e-06         78
# 7   1566625191564           0           36      7.910156e-06         84
# 8   1566625192573           0           68      1.494141e-05         94
# 9   1566625193579           0          -84     -1.845703e-05         94
# 10  1566625194587           0         1188      2.610352e-04         69
# 11  1566625195592           0         -301     -6.613770e-05         56
# ...

# %%
df.skew(axis = 0, skipna = True)
# Out:
# timestampMs         0.006442
# poorSignal          4.199069
# eegRawValue         1.075504
# eegRawValueVolts    1.075504
# attention           0.052591
# meditation         -0.101965
# blinkStrength       1.860444
# delta               6.900105
# theta               1.977388
# alphaLow            1.056282
# alphaHigh           4.195957
# betaLow             2.420546
# betaHigh            3.060309
# gammaLow            7.679969
# gammaMid            7.681071
# dtype: float64

# %%
print(df.skew())
# Out:
# timestampMs         0.006442
# poorSignal          4.199069
# eegRawValue         1.075504
# eegRawValueVolts    1.075504
# attention           0.052591
# meditation         -0.101965
# blinkStrength       1.860444
# delta               6.900105
# theta               1.977388
# alphaLow            1.056282
# alphaHigh           4.195957
# betaLow             2.420546
# betaHigh            3.060309
# gammaLow            7.679969
# gammaMid            7.681071
# dtype: float64

# %%
print(df.kurtosis())
# Out:
# timestampMs         -1.194703
# poorSignal          16.188243
# eegRawValue         12.648523
# eegRawValueVolts    12.648523
# attention           -0.936444
# meditation          -0.755199
# blinkStrength        2.263614
# delta               50.809972
# theta                1.987174
# alphaLow            -0.916309
# alphaHigh           16.154494
# betaLow              3.993490
# betaHigh             7.623132
# gammaLow            58.987676
# gammaMid            58.999222
# dtype: float64

# %%
url = "Disgust/1.csv"
names = ['delta', 'theta', 'alphaLow', 'alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammamid']
data = pd.read_csv(url, names=names)
print(data.skew())
# Out:
# timestampMs         0.006442
# poorSignal          4.199069
# eegRawValue         1.075504
# eegRawValueVolts    1.075504
# attention           0.052591
# meditation         -0.101965
# blinkStrength       1.860444
# delta               6.900105
# theta               1.977388
# alphaLow            1.056282
# alphaHigh           4.195957
# betaLow             2.420546
# betaHigh            3.060309
# gammaLow            7.679969
# gammaMid            7.681071
# dtype: float64

# %%
url = "Disgust/1.csv"
names = ['delta', 'theta', 'alphaLow', 'alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammamid']
data = pd.read_csv(url, names=names)
types = data.dtypes
print(types)
# Out:
# delta        object
# theta        object
# alphaLow     object
# alphaHigh    object
# betaLow      object
# betaHigh     object
# gammaLow     object
# gammamid     object
# dtype: object

# %%
import csv
row = ['4', '4', '4', '4', '4', '4', '4', '1']
with open('Feature/alpha.csv', 'a') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(row)

# %%
import csv
row = ['4', '4', '4', '4', '4', '4', '4', '1']
myFile = open('Feature/delta.csv', 'w')
with myFile:
    writer = csv.writer(myFile)
    writer.writerows(row)

# %%
pd.read_csv("Feature/delta.csv")
# Out:
#    4
# 0  4
# 1  4
# 2  4
# 3  4
# 4  4
# 5  4
# 6  1
